# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# %%
sent =[
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a good boy',
    'I am a good developer',
    'understand the meaning of words',
    'your videos are good',
]

# %%
##Define vocab size
voc_size = 10000

# %%
one_hot_repres = [one_hot(words,voc_size) for words in sent]

# %%
one_hot_repres
# Out:
# [[8063, 5940, 8303, 9182],
#  [8063, 5940, 8303, 9241],
#  [8063, 7967, 8303, 2540],
#  [6565, 4089, 9808, 1599, 7066],
#  [6565, 4089, 9808, 1599, 1828],
#  [8819, 8063, 5953, 8303, 1251],
#  [7201, 6533, 4863, 1599]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
sent_length = 8
embedded_docs = pad_sequences(one_hot_repres,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 8063 5940 8303 9182]
#  [   0    0    0    0 8063 5940 8303 9241]
#  [   0    0    0    0 8063 7967 8303 2540]
#  [   0    0    0 6565 4089 9808 1599 7066]
#  [   0    0    0 6565 4089 9808 1599 1828]
#  [   0    0    0 8819 8063 5953 8303 1251]
#  [   0    0    0    0 7201 6533 4863 1599]]

# %%
#feature Representation
dim =10
model = Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# array([[[ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01429781,  0.03274418,  0.03338984, -0.03149724,
#           0.03929431, -0.00350168, -0.01478752,  0.03878644,
#          -0.0480387 ,  0.04859402],
#         [-0.02737668, -0.00345862, -0.02092723,  0.02538851,
#          -0.04430642,  0.03705936,  0.04038643, -0.03925803,
#          -0.01320002, -0.03735245],
#         [ 0.02899543, -0.04363264, -0.0207863 ,  0.022602  ,
#           0.02651158,  0.01208854, -0.01918556, -0.00544314,
#           0.04723758,  0.00198676],
#         [ 0.04926786,  0.00127505,  0.03084255,  0.01619103,
#          -0.02836975,  0.01272291, -0.04437459,  0.00863413,
#           0.0047846 , -0.01988478]],
#
#        [[ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01429781,  0.03274418,  0.03338984, -0.03149724,
#           0.03929431, -0.00350168, -0.01478752,  0.03878644,
#          -0.0480387 ,  0.04859402],
#         [-0.02737668, -0.00345862, -0.02092723,  0.02538851,
#          -0.04430642,  0.03705936,  0.04038643, -0.03925803,
#          -0.01320002, -0.03735245],
#         [ 0.02899543, -0.04363264, -0.0207863 ,  0.022602  ,
#           0.02651158,  0.01208854, -0.01918556, -0.00544314,
#           0.04723758,  0.00198676],
#         [ 0.02773407,  0.03219644, -0.03968354, -0.04892129,
#           0.01537814,  0.04687014,  0.04546448,  0.0323526 ,
#           0.01304011, -0.03766346]],
#
#        [[ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01429781,  0.03274418,  0.03338984, -0.03149724,
#           0.03929431, -0.00350168, -0.01478752,  0.03878644,
#          -0.0480387 ,  0.04859402],
#         [ 0.04816755, -0.00486366,  0.03552815,  0.01073463,
#          -0.04016051,  0.03737454, -0.02257825, -0.03382339,
#           0.02456276, -0.01851543],
#         [ 0.02899543, -0.04363264, -0.0207863 ,  0.022602  ,
#           0.02651158,  0.01208854, -0.01918556, -0.00544314,
#           0.04723758,  0.00198676],
#         [-0.03808938,  0.00935569,  0.04395307,  0.01961983,
#           0.0448432 ,  0.02793387, -0.04428954, -0.02101067,
#          -0.02719027,  0.04440678]],
#
#        [[ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.03913362,  0.01069146, -0.02426251, -0.03226449,
#           0.01262749,  0.03669972,  0.02169757,  0.02643869,
#           0.04261514, -0.00581024],
#         [-0.02265437,  0.04480449,  0.03080264, -0.04690688,
#           0.01468129, -0.02021441,  0.0016369 ,  0.02494103,
#           0.0369646 ,  0.04343107],
#         [-0.0038187 ,  0.04464192,  0.01156273,  0.04789669,
#           0.020197  ,  0.01208157, -0.01640882, -0.03774339,
#          -0.02306421,  0.00252988],
#         [ 0.01700945, -0.02994367, -0.03968636, -0.04186325,
#           0.02039829,  0.01190243,  0.02813076,  0.0403502 ,
#           0.01819347, -0.01547979],
#         [-0.03264654,  0.02578831, -0.0103149 ,  0.02842153,
#          -0.00513575, -0.02166175, -0.04430064,  0.00480513,
#          -0.00402742,  0.03807903]],
#
#        [[ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.03913362,  0.01069146, -0.02426251, -0.03226449,
#           0.01262749,  0.03669972,  0.02169757,  0.02643869,
#           0.04261514, -0.00581024],
#         [-0.02265437,  0.04480449,  0.03080264, -0.04690688,
#           0.01468129, -0.02021441,  0.0016369 ,  0.02494103,
#           0.0369646 ,  0.04343107],
#         [-0.0038187 ,  0.04464192,  0.01156273,  0.04789669,
#           0.020197  ,  0.01208157, -0.01640882, -0.03774339,
#          -0.02306421,  0.00252988],
#         [ 0.01700945, -0.02994367, -0.03968636, -0.04186325,
#           0.02039829,  0.01190243,  0.02813076,  0.0403502 ,
#           0.01819347, -0.01547979],
#         [ 0.0474985 ,  0.03158266, -0.04008294, -0.00100635,
#          -0.0078578 , -0.02390455,  0.04907001,  0.03230736,
#          -0.04978424, -0.01469104]],
#
#        [[ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [-0.00567175, -0.04004468, -0.00501812, -0.01595534,
#           0.02337486, -0.02821006,  0.04148025,  0.03214302,
#          -0.02701092, -0.04409375],
#         [ 0.01429781,  0.03274418,  0.03338984, -0.03149724,
#           0.03929431, -0.00350168, -0.01478752,  0.03878644,
#          -0.0480387 ,  0.04859402],
#         [ 0.01594805,  0.00499209,  0.01025394, -0.0040343 ,
#          -0.04677951, -0.02032428,  0.01128882,  0.00296589,
#          -0.01696527,  0.02751212],
#         [ 0.02899543, -0.04363264, -0.0207863 ,  0.022602  ,
#           0.02651158,  0.01208854, -0.01918556, -0.00544314,
#           0.04723758,  0.00198676],
#         [ 0.01901836, -0.04365776,  0.00418971, -0.01998848,
#           0.02503704,  0.03858112,  0.00690554, -0.02488362,
#           0.02451655,  0.03669764]],
#
#        [[ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.01666569, -0.00933522,  0.02836515, -0.00868978,
#          -0.0065946 , -0.02562325, -0.018355  ,  0.00978292,
#          -0.02796948, -0.00673429],
#         [ 0.04554245, -0.02714931,  0.02990225,  0.00747417,
#          -0.00445475, -0.01294967, -0.01292346,  0.02001351,
#           0.03091301, -0.0315276 ],
#         [-0.00462757,  0.04194706, -0.04918487,  0.03655085,
#          -0.00130124, -0.04020119,  0.04606071, -0.03883035,
#          -0.02256771, -0.04986865],
#         [ 0.01186514,  0.04562031,  0.0044873 ,  0.00471793,
#          -0.02482529, -0.02689294,  0.01105285, -0.01766635,
#          -0.00904025, -0.00108639],
#         [ 0.01700945, -0.02994367, -0.03968636, -0.04186325,
#           0.02039829,  0.01190243,  0.02813076,  0.0403502 ,
#           0.01819347, -0.01547979]]], dtype=float32)
